# %%
import pandas as pd

# %%
billionaire=pd.read_csv("Billionaires.csv.xls")
pd.set_option("display.max_columns",85)

# %%
billionaire
# Out:
#       rank  finalWorth               category                personName   age  \
# 0        1      211000       Fashion & Retail  Bernard Arnault & family  74.0
# 1        2      180000             Automotive                 Elon Musk  51.0
# 2        3      114000             Technology                Jeff Bezos  59.0
# 3        4      107000             Technology             Larry Ellison  78.0
# 4        5      106000  Finance & Investments            Warren Buffett  92.0
# ...    ...         ...                    ...                       ...   ...
# 2635  2540        1000             Healthcare                   Yu Rong  51.0
# 2636  2540        1000        Food & Beverage    Richard Yuengling, Jr.  80.0
# 2637  2540        1000          Manufacturing             Zhang Gongyun  60.0
# 2638  2540        1000            Real Estate    Zhang Guiping & family  71.0
# 2639  2540        1000            Diversified               Inigo Zobel  66.0
#
# ...

# %%
wealth=billionaire.groupby('city')

# %%
wealth['industries'].get_group('Omaha')
# Out:
# 4       Finance & Investments
# 1230          Food & Beverage
# Name: industries, dtype: object

# %%
wealth['cpi_country'].mean()
# Out:
# city
# A Coruña     110.96
# Aarhus       110.35
# Abbeville    117.24
# Aberdeen     119.62
# Aberdyfi     119.62
#               ...
# Zhuzhou      125.08
# Zug           99.55
# Zurich        99.55
# foshan       125.08
# torino       110.62
# Name: cpi_country, Length: 741, dtype: float64

# %%
wealth['cpi_country'].median()
# Out:
# city
# A Coruña     110.96
# Aarhus       110.35
# Abbeville    117.24
# Aberdeen     119.62
# Aberdyfi     119.62
#               ...
# Zhuzhou      125.08
# Zug           99.55
# Zurich        99.55
# foshan       125.08
# torino       110.62
# Name: cpi_country, Length: 741, dtype: float64

# %%
wealth['cpi_country'].max()
# Out:
# city
# A Coruña     110.96
# Aarhus       110.35
# Abbeville    117.24
# Aberdeen     119.62
# Aberdyfi     119.62
#               ...
# Zhuzhou      125.08
# Zug           99.55
# Zurich        99.55
# foshan       125.08
# torino       110.62
# Name: cpi_country, Length: 741, dtype: float64

# %%
wealth['cpi_country'].min()
# Out:
# city
# A Coruña     110.96
# Aarhus       110.35
# Abbeville    117.24
# Aberdeen     119.62
# Aberdyfi     119.62
#               ...
# Zhuzhou      125.08
# Zug           99.55
# Zurich        99.55
# foshan       125.08
# torino       110.62
# Name: cpi_country, Length: 741, dtype: float64

# %%
weather=pd.read_csv('GlobalWeather.csv.xls')

# %%
weather
# Out:
#           country     location_name  latitude  longitude         timezone  \
# 0     Afghanistan             Kabul     34.52      69.18       Asia/Kabul
# 1         Albania            Tirana     41.33      19.82    Europe/Tirane
# 2         Algeria           Algiers     36.76       3.05   Africa/Algiers
# 3         Andorra  Andorra La Vella     42.50       1.52   Europe/Andorra
# 4          Angola            Luanda     -8.84      13.23    Africa/Luanda
# ...           ...               ...       ...        ...              ...
# 9541    Venezuela           Caracas     10.50     -66.92  America/Caracas
# 9542      Vietnam             Hanoi     21.03     105.85     Asia/Bangkok
# 9543        Yemen             Sanaa     15.35      44.21        Asia/Aden
# 9544       Zambia            Lusaka    -15.42      28.28    Africa/Lusaka
# 9545     Zimbabwe            Harare    -17.82      31.04    Africa/Harare
#
#       last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
climate=weather.groupby('country')

# %%
climate['latitude'].get_group('Albania')
# Out:
# 1       41.33
# 196     41.33
# 391     41.33
# 586     41.33
# 781     41.33
# 975     41.33
# 1170    41.33
# 1365    41.33
# 1560    41.33
# 1755    41.33
# 1950    41.33
# 2145    41.33
# 2340    41.33
# 2535    41.33
# 2730    41.33
# 2925    41.33
# 3120    41.33
# 3315    41.33
# 3510    41.33
# 3705    41.33
# 3899    41.33
# 4094    41.33
# 4288    41.33
# 4483    41.33
# 4678    41.33
# 4872    41.33
# 5066    41.33
# 5261    41.33
# 5456    41.33
# 5651    41.33
# 5842    41.33
# 6037    41.33
# 6232    41.33
# 6427    41.33
# 6622    41.33
# 6817    41.33
# 7012    41.33
# 7207    41.33
# 7402    41.33
# 7597    41.33
# 7792    41.33
# 7987    41.33
# 8182    41.33
# 8377    41.33
# 8572    41.33
# 8767    41.33
# 8962    41.33
# 9157    41.33
# 9352    41.33
# Name: latitude, dtype: float64

# %%
import numpy as np

# %%
longitude=weather['longitude']

# %%
np.var(longitude)
# Out:
# 4314.592693985903

# %%
temp=weather['temperature_celsius']

# %%
np.std(temp)
# Out:
# 7.0468567514763585

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(weather['latitude'],weather['longitude'],linestyle=':',linewidth=3,label='longitude')
plt.title('weather')
plt.grid()
plt.show()

# %%
plt.scatter(billionaire['age'],billionaire['finalWorth'],color='blue',s=50,alpha=0.5)
plt.xlabel("Billionaires Age")
plt.ylabel('Billionaires Worth')
plt.title("Billionaire Random Barplot")
plt.show()

# %%
weather1=weather.loc[:2,["latitude",'longitude','temperature_celsius']]
weather1
# Out:
#    latitude  longitude  temperature_celsius
# 0     34.52      69.18                 28.8
# 1     41.33      19.82                 27.0
# 2     36.76       3.05                 28.0

# %%
weather1.plot(kind='bar')
# Out:
# <Axes: >
